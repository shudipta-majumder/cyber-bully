# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_csv("Simple_Data_with_NID.csv")
df.tail(10)
# Out:
#                NameId                                               Text  nid
# 26932       bud448002                                    what is nuthing   45
# 26933  eveaintsogreat                                            nothing   46
# 26934       bud448002   can i leave njow (Yes for the love of all tha...   45
# 26935       bud448002                                        is mom gone   45
# 26936  eveaintsogreat                                   Yes she is gone    46
# 26937  eveaintsogreat                                           come now   46
# 26938       bud448002                                                 ok   45
# 26939       bud448002                     i an weare gray pants gray top   45
# 26940       bud448002                                                brb   45
# 26941  eveaintsogreat   ok. im gettin offline to fix my hair n run to...   46

# %%
d = pd.factorize(df['NameId'])[0]

# %%
df['nid'] = d

# %%
df.isnull().sum()
# Out:
# NameId    43
# Text      77
# nid        0
# dtype: int64

# %%
df.shape
# Out:
# (26942, 3)

# %%
df = df.fillna('')
df
# Out:
#                NameId                                               Text  nid
# 0         baby_breana       hi u sent me a email so i added u to my list    0
# 1         baby_breana                                                 hi    0
# 2         baby_breana                                                 hi    0
# 3      aladiesmasseur                               hello there my sweet    1
# 4         baby_breana                                    is ur name jim?    0
# ...               ...                                                ...  ...
# 26937  eveaintsogreat                                           come now   46
# 26938       bud448002                                                 ok   45
# 26939       bud448002                     i an weare gray pants gray top   45
# 26940       bud448002                                                brb   45
# 26941  eveaintsogreat   ok. im gettin offline to fix my hair n run to...   46
#
# [26942 rows x 3 columns]

# %%
#nltk.download()

# %%
df.dropna(axis='index', how='all')
# Out:
#                NameId                                               Text  nid
# 0         baby_breana       hi u sent me a email so i added u to my list    0
# 1         baby_breana                                                 hi    0
# 2         baby_breana                                                 hi    0
# 3      aladiesmasseur                               hello there my sweet    1
# 4         baby_breana                                    is ur name jim?    0
# ...               ...                                                ...  ...
# 26937  eveaintsogreat                                           come now   46
# 26938       bud448002                                                 ok   45
# 26939       bud448002                     i an weare gray pants gray top   45
# 26940       bud448002                                                brb   45
# 26941  eveaintsogreat   ok. im gettin offline to fix my hair n run to...   46
#
# [26942 rows x 3 columns]

# %%
#Convert to lower case all
import string
df['Text'] = [doc.lower()for doc in df['Text']]
print(df['Text'][:10])
# Out:
# 0     hi u sent me a email so i added u to my list
# 1                                               hi
# 2                                               hi
# 3                             hello there my sweet
# 4                                  is ur name jim?
# 5                                how are you doing
# 6                                  you are bad boy
# 7                                          im good
# 8                                my name is breana
# 9                                 glad to meet you
# Name: Text, dtype: object

# %%
#Tokenization
from nltk.tokenize import word_tokenize
tokenized_doc = [word_tokenize(doc) for doc in df['Text']]
# print(tokenized_doc)

# %%
custom_abbr = {
    "u" : "you",
    "k" : "ok",
    "hlw" : "hello",
    "idk" :  "i do not mind",
    "ur": "Your",
    "im": "i am",
    "sx": "sex",
    "yaa": "yet another acronym",
    "sxy": "sexy",
    "yarly": "ya, really? ",
    "yas": "meaning praise",
    "ybic": "your brother in Christ",
    "ybs": "you'll be sorry",
    "ygg": "you go girl",
    "ygtbkm": "you have got to be kidding me",
    "yl":"young lady",
    "ymmv":"your mileage may vary",
    "gd":"good night",
    "m9":"morning",
    "gdn8":"good night",

    
}
counter = 0
for index, text_list in enumerate(tokenized_doc):
    text_list = [custom_abbr[abb] if abb in custom_abbr.keys() else abb for abb in text_list]
    tokenized_doc[index] = text_list

# %%
from nltk.tokenize import sent_tokenize
sent_token = [sent_tokenize(doc) for doc in df['Text']]
# print(sent_token)

# %%
#Punctuation Remove frome sentance
regex = re.compile('[%s]' % re.escape(string.punctuation))
tokenize_doc_punc =[]
for review in tokenized_doc:
    new_review =[]
    for token in review:
        new_token = regex.sub(u'' , token)
        if not new_token == u'':
            new_review.append(new_token)
    tokenize_doc_punc.append(new_review)
#print(tokenize_doc_punc)     #tokenize_doc_punc this is total stirng vatiable

# %%
#removing stopwords
from nltk.corpus import stopwords
tokenize_doc_no_stopwords = []
for doc in tokenize_doc_punc:
    new_term_vector = []
    for word in doc:
        if not word in stopwords.words('english'):
            new_term_vector.append(word)
    tokenize_doc_no_stopwords.append(new_term_vector)
#print(tokenize_doc_no_stopwords) #String Varoable -tokenize_doc_no_stopwords

# %%
#Streming Lemnatization
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

porter = PorterStemmer()
wordnet = WordNetLemmatizer()

preprocessed_text = []
Data_ne =[]
for doc in tokenize_doc_no_stopwords:
    final_text = []
    for word in doc:
        #final_text.append(porter.stem(word))
        final_text.append(wordnet.lemmatize(word))
    preprocessed_text.append(' '.join(final_text))
    Data_ne.append(final_text)
   
print(preprocessed_text) #preprocessed_text -Final text
# Out:
# ['hi sent email added list', 'hi', 'hi', 'hello sweet', 'Your name jim', '', 'bad boy', 'i am good', 'name breana', 'glad meet', 'look profile', '', 'look', '', 'like shape look', 'aww lol thx', 'look aladiesmasseur', 'umm ok ill try', 'ok', 'whats Your asl', 'young 50 massage work', 'i am 13 f eureka', 'eureka ca', 'iam calif st', 'guy play school', '', 'touch', 'mean kinda dont know mean', 'kiss', 'lol kissed b4', 'cool', 'dress sexy sometimes', 'lol mom would get mad', 'bet', 'ever naked front guy', 'omg lol', 'would love give massage', 'relly', 'nice warm lotion body', 'never 1 b4', 'would love', 'give nice as rub', 'lol', 'way r serius', 'yeah', 'id get embaressd', 'would would make feel good', 'dunno', 'home', '1', 'asking reason wearing', 'short n tank', 'massage gently remove top', '', 'unshap bra let fall floor', 'smile lay face', 'guy ever jackt front', 'omg', 'would like see sometime', 'dunno', 'r sending pic suddenly file tranfer notice', 'yes want', '', 'surprise always take', 'ok', 'omg child porn', 'girl age sucking two guy dick', 'omg', 'take pic', 'sent', '', '', 'girl long ago', 'would let strip naked massage time placed phone call nc3tf', 'um maybe r massage naked', 'lady want', '', 'say', '', 'would like', 'dunno r relly gon na give massege', 'want one would want', 'huh', 'place motel park', 'like could come Your house give', 'sometimes one home', '', 'maybe would pour flovered lotion nipple', 'flavored', 'relly', 'use tongue lick', 'lol', 'nipple hard', 'dont think', 'put hand top rub', '', 'get nipple nice hard', '', 'forget thats ok', 'lol ok dont get', 'never seen guy cum', '', 'know tittie fucking', '', 'guy put hard dick breast go till cum face', '', 'would like hand naked body', 'dunno', 'maybe bend leg bury face leg', 'omg serious', 'would like', 'dunno', 'maybe finger tight pussy as', 'omg', 'lol', 'would like jack cum breast', 'dunno r relly serious', 'could want', 'like Your house', 'yeah maybe take park someplace quite', '', 'teach new thing', 'like wat park', 'one zoo could park walk unless want go somewhere else', 'like ppl live Your house', 'roommate female', '', 'like girl could join u', 'dunno', 'go', 'hi', 'hello', 'night', 'ok', 'cool', '', 'sorry getting away earlier today really', '', 'good', 'mean left', 'mean way talkt', 'lol', 'got call go massage', '', 'go park', 'went house', '', 'ended giving full body massage', 'never 1 b4', 'around 36 daughter got watch u', 'old dahgter', '14 think', 'watch massage', 'interested ask mom ok', '', 'hot', 'lol', 'bro si', 'little bro life dad dad gf', 'live mom', 'yah', 'bet mom would like massage way see', '', 'reason', 'see dont get watch massage', 'mom home', 'yah shes bed', 'maybe afraid getting one', '', 'girl watched', 'think', 'even showed place', '', 'massage 2', 'back mom breast', '', 'wanted', 'omg relly', 'kept thinking', '', 'picturing daughter', 'lol', 'fun nude', 'omg way', 'yes mom ask', '', 'iam told', '', 'mom bring guy home', 'bf', 'ok', '', 'asking', 'ok', 'wearing', 'pjs', 'wish could see', 'dont cam', 'grade', '7', 'cool', 'sux', 'lol', 'need someone touch', 'lol', 'wat look like', 'see profile', '', 'hit contact see profile', 'ok', 'omg whats Your nose lol', 'strapon', '', 'girl use fuck', 'omg lol', 'girl ever kisst', 'Your phone Your prof', 'yes', 'yah kissed girl b4 no1 prank cals lol', 'bad call yet like kisst', 'yah ge', 'would love slide tongue mouth', 'lol r serius jus playing', 'serious play', 'huh', 'would like', 'serious play', 'dont wan na lied seriuos ge', 'sound good never lie get nowhere', 'saw massage table costco 1 time', 'one padded like bed floor better', 'floor', 'yeah fun plus work real good', '', 'love meet park sometimes park', 'massage park', 'really ca nt make feel good', '', 'lean againest tree kiss long time', 'lol', 'put hand top', 'park', 'yeah one would see', 'r sure', 'yes', 'would show', 'lol', 'want', 'umm', 'changed name', '2 name', 'one person also night think', '', 'sent message diff name', ' ...

# %%
df['Level_Text'] = Data_ne
df['Text'] = preprocessed_text
#df['Text'][:10]
df['Level_Text'][:5]
# Out:
# 0    [hi, sent, email, added, list]
# 1                              [hi]
# 2                              [hi]
# 3                    [hello, sweet]
# 4                 [Your, name, jim]
# Name: Level_Text, dtype: object

# %%
sentimentIntensityAnalyzer = SentimentIntensityAnalyzer()

negetive = []
neutral = []
positive = []
bully = []
for index, row in df.iterrows():
    scores = sentimentIntensityAnalyzer.polarity_scores(str(row['Text']))
    
    negetive.append(scores['neg'])
    neutral.append(scores['neu'])
    positive.append(scores['pos'])
    
    if scores['neg'] and (scores['neg'] >= scores['neu'] or scores['neu'] >= scores['pos']):
        bully.append(1)  #Bullying_True
    else:
        bully.append(0)  #Bullying_False

df['Negetive'] = negetive
df['Neutral'] = neutral
df['Positive'] = positive
df['bully'] = bully
df.to_csv('TrainData.csv', index=False)

df.head(10)
# Out:
#            NameId                      Text  nid  \
# 0     baby_breana  hi sent email added list    0
# 1     baby_breana                        hi    0
# 2     baby_breana                        hi    0
# 3  aladiesmasseur               hello sweet    1
# 4     baby_breana             Your name jim    0
# 5  aladiesmasseur                              1
# 6  aladiesmasseur                   bad boy    1
# 7     baby_breana                 i am good    0
# 8     baby_breana               name breana    0
# 9  aladiesmasseur                 glad meet    1
#
#                        Level_Text  Negetive  Neutral  Positive  bully
# 0  [hi, sent, email, added, list]     0.000    1.000     0.000      0
# 1                            [hi]     0.000    1.000     0.000      0
# 2                            [hi]     0.000    1.000     0.000      0
# 3                  [hello, sweet]     0.000    0.250     0.750      0
# 4               [Your, name, jim]     0.000    1.000     0.000      0
# 5                              []     0.000    0.000     0.000      0
# 6                      [bad, boy]     0.778    0.222     0.000      1
# 7                    [i am, good]     0.000    0.256     0.744      0
# 8                  [name, breana]     0.000    1.000     0.000      0
# 9                    [glad, meet]     0.000    0.250     0.750      0
